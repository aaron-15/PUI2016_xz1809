# %%
# import all the things together
import numpy as np
import pylab as pl
import pandas as pd
import os
import csv
from matplotlib.dates import date2num
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# check that environmental variable exist
path = os.getenv("DFDATA")
path
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
# take hours to understand jb3k-j3gp still contains many files, 1427553519 is the key
filename = 'jb3k-j3gp/1438440620/jb3k-j3gp'

# %%
# use Pandas to read data from csv file
data = pd.read_csv(path + '/' + filename)

# display the top few rows
data.head()
# Out:
#    License Number               Name                   Type Expiration Date  \
# 0          501089    GOITA,SOULEMANE  MEDALLION TAXI DRIVER      09/14/2015
# 1          501304        ALAM,ZASHIB  MEDALLION TAXI DRIVER      09/19/2016
# 2          501308  OYELADE,SOLOMON,A  MEDALLION TAXI DRIVER      09/29/2016
# 3          501688     DAHBI,MOHAMMED  MEDALLION TAXI DRIVER      09/02/2016
# 4          494496          SINGH,RAM  MEDALLION TAXI DRIVER      05/31/2017
#
#   Last Date Updated Last Time Updated
# 0        08/01/2015             13:20
# 1        08/01/2015             13:20
# 2        08/01/2015             13:20
# 3        08/01/2015             13:20
# 4        08/01/2015             13:20

# %%
# choose two numerical columns that I want to keep
data_part = data[['License Number','Expiration Date']]

# try to drop
#data.drop(['Name','Type'],axis =2)


#type(data_part)

# add column's title
data_part.columns = ['License','Expiration']

# see what it looks like
data_part.head()
# Out:
#    License  Expiration
# 0   501089  09/14/2015
# 1   501304  09/19/2016
# 2   501308  09/29/2016
# 3   501688  09/02/2016
# 4   494496  05/31/2017

# %%
# output the dataframe
data_part
# Out:
#        License  Expiration
# 0       501089  09/14/2015
# 1       501304  09/19/2016
# 2       501308  09/29/2016
# 3       501688  09/02/2016
# 4       494496  05/31/2017
# 5       495368  09/16/2016
# 6       495642  09/30/2016
# 7       499290  04/17/2017
# 8       501608  08/31/2016
# 9       501854  09/14/2016
# 10      495886  11/27/2016
# 11      500883  09/30/2015
# 12      501828  08/27/2016
# 13      501946  09/16/2016
# 14      495300  08/12/2016
# 15      495931  09/23/2015
# 16      495048  09/13/2016
# 17      495138  08/10/2016
# 18      495155  09/07/2015
# 19      500921  09/23/2015
# 20      501260  09/23/2016
# 21      501536  09/14/2016
# 22      502075  09/19/2015
# 23      495109  09/19/2015
# 24      499700  09/02/2016
# 25      500382  09/12/2016
# 26      500531  09/06/2015
# 27      500649  09/26/2015
# 28      501093  09/03/2015
# 29      501183  09/14/2015
# ...        ...         ...
# 52666  5575400  12/09/2015
# 52667  5575436  12/24/2015
# ...

# %%
# ready to plot
import matplotlib.pyplot as plt
ax = data_part.plot.scatter(x='Expiration',y='License',alpha = 0.2)
ax.set_title('Medallion Drivers')
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-43-5e5a11e5a653> in <module>()
#       1 # ready to plot
# ----> 2 ax = data_part.plot.scatter(x='Expiration',y='License',alpha = 0.2)
#       3 ax.set_title('Medallion Drivers')
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in scatter(self, x, y, s, c, **kwds)
#    3916         axes : matplotlib.AxesSubplot or np.array of them
#    3917         """
# -> 3918         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3919
#    3920     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...
